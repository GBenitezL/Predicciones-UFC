# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("data.csv")
df2 = pd.read_csv("data2.csv")

# %%
df = df2.loc[:, df2.columns.isin(df.columns.tolist())]

# %%
df.head()
# Out:
#           R_fighter              B_fighter        Referee        date  \
# 0  Marina Rodriguez           Amanda Lemos   Jason Herzog  2022-11-05
# 1    Darrick Minner  Shayilan Nuerdanbieke     Mark Smith  2022-11-05
# 2        Neil Magny       Daniel Rodriguez      Herb Dean  2022-11-05
# 3   Tagir Ulanbekov            Nate Maness  Chris Tognoni  2022-11-05
# 4    Mario Bautista           Benito Lopez  Chris Tognoni  2022-11-05
#
#                  location Winner  title_bout      weight_class  B_avg_KD  \
# 0  Las Vegas, Nevada, USA   Blue       False  WomenStrawweight  0.265625
# 1  Las Vegas, Nevada, USA   Blue       False     Featherweight  0.500000
# 2  Las Vegas, Nevada, USA    Red       False      Welterweight  0.054688
# 3  Las Vegas, Nevada, USA    Red       False         Flyweight  0.375000
# 4  Las Vegas, Nevada, USA    Red       False      Bantamweight  0.250000
#
#    B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  \
# ...

# %%
df['gender'] = np.where(df['weight_class'].str.contains('Women'), "Women's", "Men's")
# Out:
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_14836\2131024506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = np.where(df['weight_class'].str.contains('Women'), "Women's", "Men's")

# %%
df['year'] = df['date'].str[0:4]
# Out:
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_14836\155635252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['date'].str[0:4]

# %%
df_date_range = df[df['date'] > '2010']

# %%
df_subset = df_date_range
# [["R_fighter","B_fighter", "gender", "weight_class", "R_age", "B_age", "R_Stance", "B_Stance", "R_Weight_lbs", "B_Weight_lbs", "R_Reach_cms", "B_Reach_cms", "R_wins", "B_wins", "R_losses", "B_losses", "R_current_win_streak", "B_current_win_streak", 
                        #    "R_current_lose_streak", "B_current_lose_streak","R_longest_win_streak", "B_longest_win_streak", "Winner"]]

# %%
df_subset.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner',
#        'title_bout', 'weight_class', 'B_avg_KD', 'B_avg_opp_KD',
#        ...
#        'R_win_by_Submission', 'R_win_by_TKO_Doctor_Stoppage', 'R_Stance',
#        'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs', 'B_age', 'R_age',
#        'gender', 'year'],
#       dtype='object', length=142)

# %%
df_subset.isna().sum()
# Out:
# R_fighter                          0
# B_fighter                          0
# Referee                           31
# date                               0
# location                           0
# Winner                             1
# title_bout                         0
# weight_class                       0
# B_avg_KD                        1126
# B_avg_opp_KD                    1126
# B_avg_SIG_STR_pct               1126
# B_avg_opp_SIG_STR_pct           1126
# B_avg_TD_pct                    1126
# B_avg_opp_TD_pct                1126
# B_avg_SUB_ATT                   1126
# B_avg_opp_SUB_ATT               1126
# B_avg_REV                       1126
# B_avg_opp_REV                   1126
# B_avg_SIG_STR_att               1126
# B_avg_SIG_STR_landed            1126
# B_avg_opp_SIG_STR_att           1126
# B_avg_opp_SIG_STR_landed        1126
# B_avg_TOTAL_STR_att             1126
# B_avg_TOTAL_STR_landed          1126
# B_avg_opp_TOTAL_STR_att         1126
# ...

# %%
UFC = df_subset.dropna()

# %%
UFC.groupby("gender").describe()
# Out:
#         B_avg_KD                                                          \
#            count      mean       std  min  25%       50%       75%   max
# gender
# Men's     3667.0  0.276235  0.377953  0.0  0.0  0.070312  0.500000  3.00
# Women's    432.0  0.083209  0.202314  0.0  0.0  0.000000  0.015625  1.25
#
#         B_avg_opp_KD                                                \
#                count      mean       std  min  25%  50%   75%  max
# gender
# Men's         3667.0  0.183815  0.316885  0.0  0.0  0.0  0.25  3.0
# Women's        432.0  0.069183  0.181020  0.0  0.0  0.0  0.00  1.0
#
#         B_avg_SIG_STR_pct                                                \
#                     count      mean       std   min       25%       50%
# gender
# Men's              3667.0  0.457025  0.118501  0.00  0.384065  0.452500
# Women's             432.0  0.469798  0.103578  0.16  0.395000  0.470156
#
#                         B_avg_opp_SIG_STR_pct                           \
# ...

# %%
UFC['weight_class'] = np.where(UFC.weight_class.str.startswith('Women'), UFC.weight_class.str[:5] + "'s " + UFC.weight_class.str[5:], UFC.weight_class.str[:])
UFC['weight_class'] = np.where(UFC.weight_class.str.startswith('Catch') | UFC.weight_class.str.startswith('LightH'), UFC.weight_class.str[:5] + " " + UFC.weight_class.str[5:], UFC.weight_class.str[:])
# Out:
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_14836\1449015300.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UFC['weight_class'] = np.where(UFC.weight_class.str.startswith('Women'), UFC.weight_class.str[:5] + "'s " + UFC.weight_class.str[5:], UFC.weight_class.str[:])
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_14836\1449015300.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
UFC.groupby(["gender", "weight_class"]).mean(numeric_only = True)
# Out:
#                                title_bout  B_avg_KD  B_avg_opp_KD  \
# gender  weight_class
# Men's   Bantamweight             0.049223  0.267388      0.191081
#         Catch Weight             0.000000  0.181742      0.175390
#         Featherweight            0.040685  0.236242      0.146843
#         Flyweight                0.103627  0.271429      0.164595
#         Heavyweight              0.063253  0.336667      0.194183
#         Light Heavyweight        0.066852  0.306015      0.227243
#         Lightweight              0.032857  0.231171      0.173061
#         Middleweight             0.043053  0.270052      0.170897
#         Welterweight             0.036337  0.319689      0.203479
# Women's Women's Bantamweight     0.129310  0.077690      0.085626
#         Women's Featherweight    0.384615  0.191707      0.067308
#         Women's Flyweight        0.061069  0.100729      0.063295
#         Women's Strawweight      0.081395  0.065386      0.062719
#
# ...

# %%
UFC.head()
# Out:
#           R_fighter              B_fighter        Referee        date  \
# 0  Marina Rodriguez           Amanda Lemos   Jason Herzog  2022-11-05
# 1    Darrick Minner  Shayilan Nuerdanbieke     Mark Smith  2022-11-05
# 2        Neil Magny       Daniel Rodriguez      Herb Dean  2022-11-05
# 3   Tagir Ulanbekov            Nate Maness  Chris Tognoni  2022-11-05
# 4    Mario Bautista           Benito Lopez  Chris Tognoni  2022-11-05
#
#                  location Winner  title_bout         weight_class  B_avg_KD  \
# 0  Las Vegas, Nevada, USA   Blue       False  Women's Strawweight  0.265625
# 1  Las Vegas, Nevada, USA   Blue       False        Featherweight  0.500000
# 2  Las Vegas, Nevada, USA    Red       False         Welterweight  0.054688
# 3  Las Vegas, Nevada, USA    Red       False            Flyweight  0.375000
# 4  Las Vegas, Nevada, USA    Red       False         Bantamweight  0.250000
#
#    B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  \
# ...

# %%
UFC.to_csv('UFC_limpio.csv', index=False)
